# %%
import requests

# Replace this with your actual Bearer Token
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAAV8wAEAAAAApmJ8ItjlvYaUA3yvECSI9l048L8%3D9bSTWxNGdJzBrb8u9BhzTPEdzDPLyubvc9z0fUhvLduRKMVz0A'

# Function to create headers for authorization
def create_headers(bearer_token):
    headers = {
        "Authorization": f"Bearer {bearer_token}",
        "Content-Type": "application/json"
    }
    return headers

# Function to search tweets by hashtag
def search_tweets_by_hashtag(hashtag, max_results=10):
    search_url = "https://api.twitter.com/2/tweets/search/recent"

    # URL-encode the hashtag (use %23 to represent the # symbol)
    query = f"%23{hashtag} lang:en"

    # Define the parameters for the search
    query_params = {
        'query': "elections",  # Hashtag search
        'max_results': 10,  # Maximum number of tweets to retrieve (between 10 and 100)
        'tweet.fields': 'created_at,author_id,text,public_metrics',  # Optional: Specify additional fields
    }

    # Send the GET request
    headers = create_headers(BEARER_TOKEN)
    response = requests.get(search_url, headers=headers, params=query_params)

    # Check for a successful request
    if response.status_code == 200:
        return response.json()  # Return the tweet data in JSON format
    else:
        print(f"Error: {response.status_code}, {response.text}")
        return None

# Example usage: Search for tweets with the hashtag #USElections
tweets = search_tweets_by_hashtag("USElections", max_results=5)

# Print the fetched tweets
if tweets and 'data' in tweets:
    for tweet in tweets['data']:
        print(f"Tweet ID: {tweet['id']}")
        print(f"Author ID: {tweet['author_id']}")
        print(f"Created at: {tweet['created_at']}")
        print(f"Tweet: {tweet['text']}")
        print(f"Retweets: {tweet['public_metrics']['retweet_count']}, Likes: {tweet['public_metrics']['like_count']}")
        print("-" * 50)
# Out:
# Tweet ID: 1840161592652013757
# Author ID: 252304755
# Created at: 2024-09-28T22:48:06.000Z
# Tweet: RT @walkswithhawk: So it occurred to me today what happens with the elections in the hurricane ravaged areas?
# Retweets: 2, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161590005387528
# Author ID: 365260012
# Created at: 2024-09-28T22:48:06.000Z
# Tweet: RT @GadSaad: This guy is insane.  If the Supreme Court no longer bends liberal then get rid of it.  If we can't win via the Electoral Colle…
# Retweets: 3929, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161586939637764
# Author ID: 1813018564883820544
# Created at: 2024-09-28T22:48:05.000Z
# Tweet: RT @GadSaad: This guy is insane.  If the Supreme Court no longer bends liberal then get rid of it.  If we can't win via the Electoral Colle…
# Retweets: 3929, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161584859230704
# Author ID: 1657737825956294663
# Created at: 2024-09-28T22:48:05.000Z
# Tweet: RT @Q_STAGE: $Q_Stage We've launched! We are coming to change the concept of elections!
# Our election PROMISE  is to send a ROCKET to the M…
# Retweets: 74, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161581432483910
# Author ID: 1330141625079705601
# Created at: 2024-09-28T22:48:04.000Z
# Tweet: RT @mickaBabayaga: Coach : Allez benoît pense au templier et au score de la France insoumise au élections https://t.co/IhcYOia8Qn
# Retweets: 6, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161579004039278
# Author ID: 2678464519
# Created at: 2024-09-28T22:48:03.000Z
# Tweet: @maddenifico Zelensky bans elections, political opposition, free press, free speech and religious freedom but, according to you, he’s fighting for democracy.
#
# Sometimes it’s best to say nothing than to talk and let the whole world know you are an intellectual lightweight.
#
# Your democracy… https://t.co/eoEPJXpyCK
# Retweets: 0, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161578664042637
# Author ID: 1835452232671633408
# Created at: 2024-09-28T22:48:03.000Z
# Tweet: RT @TRUMP_ARMY_: @elonmusk Both are fighting to secure American Elections!! https://t.co/zvkxmVeSXt
# Retweets: 139, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161571852394537
# Author ID: 948967128
# Created at: 2024-09-28T22:48:01.000Z
# Tweet: RT @Mightfo: if you're texan, check if youve been purged randomly. Also, Ted Cruz  only got 200,000 more votes(not a big % of the populatio…
# Retweets: 1, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161570627957195
# Author ID: 1750207549490552833
# Created at: 2024-09-28T22:48:01.000Z
# Tweet: RT @reformparty_uk: Reform UK is Britain’s fastest growing political movement. We are getting ready to fight and win elections across the c…
# Retweets: 517, Likes: 0
# --------------------------------------------------
# Tweet ID: 1840161570191511620
# Author ID: 1337833534048841728
# Created at: 2024-09-28T22:48:01.000Z
# Tweet: RT @_pagupagu: @f_asselineau Le RN qui a permis à Macron de remporter les élections de 2017 et 2020 ne votera pas la destitution. Et quand…
# Retweets: 5, Likes: 0
# --------------------------------------------------
